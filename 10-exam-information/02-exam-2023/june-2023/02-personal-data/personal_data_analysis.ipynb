# %% [markdown]
# Je krijgt van ons een csv bestand met de naam “persoonsgegevens.csv”.
# Het bestand bevat informatie van personen:
# -	Kolom 1: het rijksregisternummer van de persoon
# -	Kolom 2: de familienaam van de persoon
# -	Kolom 3: de voornaam van de persoon
#
# Een rijksregisternummer heeft volgend formaat:
# -	3 keer 2 cijfers onderling gescheiden door een punt; dit is de geboortedatum van de persoon in de vorm jj.mm.dd (eerste twee cijfers zijn de 2 laatste cijfers van het geboortejaar, dan een punt, dan twee cijfers overeenkomstig de geboortemaand, dan een punt en dan nog eens twee cijfers overeenkomstig de geboortedag)
# -	Een streepje “-“
# -	Drie cijfers: dit is volgnummer om personen die op dezelfde dag geboren zijn van elkaar te onderscheiden; vrouwen krijgen een even volgnummer, mannen een oneven volgnummer
# -	Een punt
# -	Twee cijfers die als controlegetal werken; hoe deze controle gebeurd is voor deze opgave niet van belang
# Een vrouw geboren op 28 juli 1994 zou volgend rijksregisternummer kunnen hebben:
# 94.07.28-124.89.
# We wensen een applicatie te maken om een overzicht te creëren van het aantal geboortes per dag van de week. In dit overzicht worden de dagen van de week voorgesteld met de Engelstalige benamingen, dus van "Monday" tot "Sunday".
# Vul in volgende de nodige stukjes code toe.

# %% [markdown]
# Lees het bestand "personal_data.csv" in een panda Dataframe met de naam "data"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from datetime import datetime
data = pd.read_csv("personal_data.csv", sep = ";")
data
# Out:
#    rijksregisternummer      naam voornaam
# 0      94.07.25-124.89   Lemmens     Elke
# 1      96.99.11-133.71  Janssens      Jef
# 2     02.122.12-122.32      Elen  Marieke
# 3      99.07.01-005.56  Hendriks  Hendrik
# 4     93.07.25-1248.89   Lemmens     Elke
# 5      00.10.11-133.71  Janssens      Jef
# 6     12.122.12-122.32      Elen  Marieke
# 7      89.07.01-005.56  Hendriks  Hendrik
# 8      99.07.25-124.89   Lemmens     Elke
# 9      95.10.11-133.71  Janssens      Jef
# 10     12.12.12-122.32      Elen  Marieke
# 11     19.07.01-005.56  Hendriks  Hendrik
# 12     93.07.25-124.89   Lemmens     Elke
# 13     87.10.11-133.71  Janssens      Jef
# 14     12.12.22-122.32      Elen  Marieke
# 15     39.07.01-005.56  Hendriks  Hendrik
# 16     04.07.25-124.89   Lemmens     Elke
# 17     06.10.11-133.71  Janssens      Jef
# 18     22.12.12-122.32      Elen  Marieke
# 19     49.07.01-005.56  Hendriks  Hendrik
# 20     43.07.25-124.89   Lemmens     Elke
# 21     01.10.11-133.71  Janssens      Jef
# 22    32.122.12-122.32      Elen  Marieke
# 23     88.07.01-005.56  Hendriks  Hendrik
# 24     90.07.25-124.89   Lemmens     Elke
# 25     25.10.11-133.71  Janssens      Jef
# 26     14.12.12-122.32      Elen  Marieke
# 27     79.07.01-005.56  Hendriks  Hendrik
# 28     73.07.25-124.88   Lemmens     Elke
# 29     77.10.11-133.71  Janssens      Jef
# 30     62.12.22-122.32      Elen  Marieke
# 31     49.07.01-005.56  Hendriks  Hendrik

# %% [markdown]
# Controleer of dit goed gedaan is door een aantal van de eerste rijen te tonen.

# %%
data.head(10)
# Out:
#   rijksregisternummer      naam voornaam
# 0     94.07.25-124.89   Lemmens     Elke
# 1     96.99.11-133.71  Janssens      Jef
# 2    02.122.12-122.32      Elen  Marieke
# 3     99.07.01-005.56  Hendriks  Hendrik
# 4    93.07.25-1248.89   Lemmens     Elke
# 5     00.10.11-133.71  Janssens      Jef
# 6    12.122.12-122.32      Elen  Marieke
# 7     89.07.01-005.56  Hendriks  Hendrik
# 8     99.07.25-124.89   Lemmens     Elke
# 9     95.10.11-133.71  Janssens      Jef

# %% [markdown]
# Wijzig de rijksregisternummers die niet aan het juiste formaat voldoen (beschouw voorlopig enkel als goed formaat : 2cijfers.2cijfers.2cijfers-3cijfers.2cijfers) door None.
# Toon opnieuw de eerste rijen om na te gaan of dit gelukt is.

# %%
    


def check_rnumber(rijksnr):
    pattern = "\d{2}\.\d{2}\.\d{2}\-\d{3}\.\d{2}"
    if re.fullmatch(pattern, rijksnr):
        return rijksnr
    else:
        return None
    
#check_rnumber("62.12.22-122.32")

data["rijksregisternummer"] = data["rijksregisternummer"].apply(check_rnumber)
# with apply 0 is every row and 1 is every column
data = data.dropna()

data
# Out:
#    rijksregisternummer      naam voornaam
# 0      94.07.25-124.89   Lemmens     Elke
# 1      96.99.11-133.71  Janssens      Jef
# 3      99.07.01-005.56  Hendriks  Hendrik
# 5      00.10.11-133.71  Janssens      Jef
# 7      89.07.01-005.56  Hendriks  Hendrik
# 8      99.07.25-124.89   Lemmens     Elke
# 9      95.10.11-133.71  Janssens      Jef
# 10     12.12.12-122.32      Elen  Marieke
# 11     19.07.01-005.56  Hendriks  Hendrik
# 12     93.07.25-124.89   Lemmens     Elke
# 13     87.10.11-133.71  Janssens      Jef
# 14     12.12.22-122.32      Elen  Marieke
# 15     39.07.01-005.56  Hendriks  Hendrik
# 16     04.07.25-124.89   Lemmens     Elke
# 17     06.10.11-133.71  Janssens      Jef
# 18     22.12.12-122.32      Elen  Marieke
# 19     49.07.01-005.56  Hendriks  Hendrik
# 20     43.07.25-124.89   Lemmens     Elke
# 21     01.10.11-133.71  Janssens      Jef
# 23     88.07.01-005.56  Hendriks  Hendrik
# 24     90.07.25-124.89   Lemmens     Elke
# 25     25.10.11-133.71  Janssens      Jef
# 26     14.12.12-122.32      Elen  Marieke
# 27     79.07.01-005.56  Hendriks  Hendrik
# 28     73.07.25-124.88   Lemmens     Elke
# 29     77.10.11-133.71  Janssens      Jef
# 30     62.12.22-122.32      Elen  Marieke
# 31     49.07.01-005.56  Hendriks  Hendrik

# %% [markdown]
# Wijzig de rijksregisternummers waarvan de eerste 8 tekens niet overeenkomen met een datum door None.
# Toon opnieuw de eerste rijen om na te gaan of dit gelukt is.

# %%
def valid_date(rijksnr):
   try: 
       pd.to_datetime(rijksnr[0:8],format="%y.%m.%d")
       return rijksnr
   except:
       return None

valid_date("02.05.23")

data["rijksregisternummer"] = data["rijksregisternummer"].apply(valid_date)
data = data.dropna() #remove None values
data
# Out:
# /var/folders/g8/t68w4q4s51j58_dyy6zg7z700000gn/T/ipykernel_10611/2421129748.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["rijksregisternummer"] = data["rijksregisternummer"].apply(valid_date)
#    rijksregisternummer      naam voornaam  Birthdate  \
# 0      94.07.25-124.89   Lemmens     Elke 1994-07-25
# 3      99.07.01-005.56  Hendriks  Hendrik 1999-07-01
# 5      00.10.11-133.71  Janssens      Jef 2000-10-11
# 7      89.07.01-005.56  Hendriks  Hendrik 1989-07-01
# 8      99.07.25-124.89   Lemmens     Elke 1999-07-25
# 9      95.10.11-133.71  Janssens      Jef 1995-10-11
# 10     12.12.12-122.32      Elen  Marieke 2012-12-12
# 11     19.07.01-005.56  Hendriks  Hendrik 2019-07-01
# 12     93.07.25-124.89   Lemmens     Elke 1993-07-25
# 13     87.10.11-133.71  Janssens      Jef 1987-10-11
# 14     12.12.22-122.32      Elen  Marieke 2012-12-22
# 15     39.07.01-005.56  Hendriks  Hendrik 2039-07-01
# 16     04.07.25-124.89   Lemmens     Elke 2004-07-25
# 17     06.10.11-133.71  Janssens      Jef 2006-10-11
# 18     22.12.12-122.32      Elen  Marieke 2022-12-12
# 19     49.07.01-005.56  Hendriks  Hendrik 2049-07-01
# 20     43.07.25-124.89   Lemmens     Elke 2043-07-25
# 21     01.10.11-133.71  Janssens      Jef 2001-10-11
# 23     88.07.01-005.56  Hendriks  Hendrik 1988-07-01
# 24     90.07.25-124.89   Lemmens     Elke 1990-07-25
# 25     25.10.11-133.71  Janssens      Jef 2025-10-11
# 26     14.12.12-122.32      Elen  Marieke 2014-12-12
# 27     79.07.01-005.56  Hendriks  Hendrik 1979-07-01
# 28     73.07.25-124.88   Lemmens     Elke 1973-07-25
# 29     77.10.11-133.71  Janssens      Jef 1977-10-11
# 30     62.12.22-122.32      Elen  Marieke 2062-12-22
# 31     49.07.01-005.56  Hendriks  Hendrik 2049-07-01
#
#                                                   Day
# 0   <bound method PandasDelegate._add_delegate_acc...
# 3   <bound method PandasDelegate._add_delegate_acc...
# 5   <bound method PandasDelegate._add_delegate_acc...
# 7   <bound method PandasDelegate._add_delegate_acc...
# 8   <bound method PandasDelegate._add_delegate_acc...
# 9   <bound method PandasDelegate._add_delegate_acc...
# 10  <bound method PandasDelegate._add_delegate_acc...
# 11  <bound method PandasDelegate._add_delegate_acc...
# 12  <bound method PandasDelegate._add_delegate_acc...
# 13  <bound method PandasDelegate._add_delegate_acc...
# 14  <bound method PandasDelegate._add_delegate_acc...
# 15  <bound method PandasDelegate._add_delegate_acc...
# 16  <bound method PandasDelegate._add_delegate_acc...
# 17  <bound method PandasDelegate._add_delegate_acc...
# 18  <bound method PandasDelegate._add_delegate_acc...
# 19  <bound method PandasDelegate._add_delegate_acc...
# 20  <bound method PandasDelegate._add_delegate_acc...
# 21  <bound method PandasDelegate._add_delegate_acc...
# 23  <bound method PandasDelegate._add_delegate_acc...
# 24  <bound method PandasDelegate._add_delegate_acc...
# 25  <bound method PandasDelegate._add_delegate_acc...
# 26  <bound method PandasDelegate._add_delegate_acc...
# 27  <bound method PandasDelegate._add_delegate_acc...
# 28  <bound method PandasDelegate._add_delegate_acc...
# 29  <bound method PandasDelegate._add_delegate_acc...
# 30  <bound method PandasDelegate._add_delegate_acc...
# 31  <bound method PandasDelegate._add_delegate_acc...

# %% [markdown]
# Schrap de rijen in het dataframe waarin de waarde None in één van de kolommen voorkomt.
# Toon opnieuw de eerste rijen om na te gaan of dit gelukt is.

# %%
# Out:
# Timestamp('1900-01-23 00:00:00')

# %% [markdown]
# Wijzig het dataframe door een kolom toe te voegen met de naam “geboortedatum” die de geboortedatum als datetime object voorstelt.
# Toon opnieuw de eerste rijen om na te gaan of dit gelukt is.

# %%
    
data["Birthdate"] = data["rijksregisternummer"].apply(lambda x : pd.to_datetime(x[0:8], format="%y.%m.%d"))
data
# Out:
#    rijksregisternummer      naam voornaam  Birthdate        Day
# 0      94.07.25-124.89   Lemmens     Elke 1994-07-25     Monday
# 3      99.07.01-005.56  Hendriks  Hendrik 1999-07-01   Thursday
# 5      00.10.11-133.71  Janssens      Jef 2000-10-11  Wednesday
# 7      89.07.01-005.56  Hendriks  Hendrik 1989-07-01   Saturday
# 8      99.07.25-124.89   Lemmens     Elke 1999-07-25     Sunday
# 9      95.10.11-133.71  Janssens      Jef 1995-10-11  Wednesday
# 10     12.12.12-122.32      Elen  Marieke 2012-12-12  Wednesday
# 11     19.07.01-005.56  Hendriks  Hendrik 2019-07-01     Monday
# 12     93.07.25-124.89   Lemmens     Elke 1993-07-25     Sunday
# 13     87.10.11-133.71  Janssens      Jef 1987-10-11     Sunday
# 14     12.12.22-122.32      Elen  Marieke 2012-12-22   Saturday
# 15     39.07.01-005.56  Hendriks  Hendrik 2039-07-01     Friday
# 16     04.07.25-124.89   Lemmens     Elke 2004-07-25     Sunday
# 17     06.10.11-133.71  Janssens      Jef 2006-10-11  Wednesday
# 18     22.12.12-122.32      Elen  Marieke 2022-12-12     Monday
# 19     49.07.01-005.56  Hendriks  Hendrik 2049-07-01   Thursday
# 20     43.07.25-124.89   Lemmens     Elke 2043-07-25   Saturday
# 21     01.10.11-133.71  Janssens      Jef 2001-10-11   Thursday
# 23     88.07.01-005.56  Hendriks  Hendrik 1988-07-01     Friday
# 24     90.07.25-124.89   Lemmens     Elke 1990-07-25  Wednesday
# 25     25.10.11-133.71  Janssens      Jef 2025-10-11   Saturday
# 26     14.12.12-122.32      Elen  Marieke 2014-12-12     Friday
# 27     79.07.01-005.56  Hendriks  Hendrik 1979-07-01     Sunday
# 28     73.07.25-124.88   Lemmens     Elke 1973-07-25  Wednesday
# 29     77.10.11-133.71  Janssens      Jef 1977-10-11    Tuesday
# 30     62.12.22-122.32      Elen  Marieke 2062-12-22     Friday
# 31     49.07.01-005.56  Hendriks  Hendrik 2049-07-01   Thursday

# %% [markdown]
# Wijzig het dataframe door een kolom toe te voegen met de naam “dag” die de dag in de week voorstelt dat de persoon geboren is; de dagen zijn de Engelstalige namen voor de dagen.
# Toon opnieuw de eerste rijen om na te gaan of dit gelukt is.

# %%
data["Day"] = data["Birthdate"].dt.day_name()

data = data.sort_values(by="Day", ascending= True)

# %% [markdown]
# Voer volgend stukje code uit.

# %%
data["dag"] = pd.Categorical(data["dag"],["Monday","Tuesday", "Wednesday", "Thursday","Friday","Saturday","Sunday"])
data.head()

# %% [markdown]
# Toon een visueel overzicht in de vorm van een histogram van het aantal geboortes per dag van de week.

# %%
plt.figure
plt.hist(data["Day"])
# Out:
# (array([4., 3., 0., 4., 0., 5., 4., 0., 1., 6.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)
